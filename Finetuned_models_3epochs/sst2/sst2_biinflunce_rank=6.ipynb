# %%
# !pip install datasets
# !pip install transformers
# !pip install peft
# !pip install evaluate
# !pip install -U datasets==2.20.0 pyarrow==15.0.2 transformers==4.44.2 evaluate==0.4.2 --no-cache-dir
# !pip install -q datasets evaluate accelerate scikit-learn pandas matplotlib
# !pip install -U "transformers>=4.41" accelerate safetensors
# !pip install -U bitsandbytes

# %%
# !pip install --upgrade --no-cache-dir git+https://github.com/Shannu3766/bi_influence.git@version_1

# %%
import warnings
import os
import logging
os.environ["WANDB_DISABLED"] = "true"
os.environ["TRANSFORMERS_NO_ADVISORY_WARNINGS"] = "true"
os.environ["HF_HUB_DISABLE_PROGRESS_BARS"] = "1"
os.environ["TOKENIZERS_PARALLELISM"] = "false"
warnings.filterwarnings("ignore")
# logging.set_verbosity_error()

# %%
# from datasets import load_dataset, DatasetDict, Dataset

# from transformers import (
#     AutoTokenizer,
#     AutoConfig,
#     AutoModelForSequenceClassification,
#     DataCollatorWithPadding,
#     TrainingArguments,
#     Trainer)

# from peft import PeftModel, PeftConfig, get_peft_model, LoraConfig
# import evaluate
# import torch
# import numpy as np
# import os
# from transformers import AutoTokenizer, AutoModelForCausalLM, TrainingArguments, Trainer
# from peft import get_peft_model, LoraConfig, TaskType
# from torch.utils.data import DataLoader
# from adaptive_lora.callbacks import AdaptiveLoRACallback
# import numpy as np
# print("torch:", torch.__version__)
# print("cuda devices:", torch.cuda.device_count())

# %%
import os
import warnings
import torch
import numpy as np
from datasets import load_dataset
from transformers import (
    AutoTokenizer,
    AutoModelForSequenceClassification,
    DataCollatorWithPadding,
    TrainingArguments,
    Trainer,
    logging
)
from peft import get_peft_model, LoraConfig
import evaluate

# %%
# Silence all unnecessary outputs
os.environ["WANDB_DISABLED"] = "true"
os.environ["TOKENIZERS_PARALLELISM"] = "false"
warnings.filterwarnings("ignore")
logging.set_verbosity_error()

# %%
from datasets import load_dataset
import time

def load_dataset_with_retry(path, name=None, max_retries=None, wait=2):

    attempt = 0

    while True:
        try:
            if name is not None:
                ds = load_dataset(path, name)
            else:
                ds = load_dataset(path)

            print(f"Dataset loaded successfully after {attempt} attempts.")
            return ds

        except Exception as e:
            attempt += 1
            wait_time = wait * min(5, attempt)  

            print(f"[Attempt {attempt}] Failed to load dataset: {e}")
            print(f"Retrying in {wait_time} seconds...\n")

            if max_retries is not None and attempt >= max_retries:
                print("Max retries reached. Raising error.")
                raise e

            time.sleep(wait_time)
dataset = load_dataset_with_retry("glue", "sst2")
# Out:
# Dataset loaded successfully after 0 attempts.

# %%
model_checkpoint = "TinyLlama/TinyLlama-1.1B-Chat-v1.0"
id2label = {0: "Negative", 1: "Positive"}
label2id = {"Negative": 0, "Positive": 1}

model = AutoModelForSequenceClassification.from_pretrained(
    model_checkpoint,
    num_labels=2,
    id2label=id2label,
    label2id=label2id,
    device_map="auto"
)

# %%
from transformers import AutoTokenizer, DataCollatorWithPadding

tokenizer = AutoTokenizer.from_pretrained(model_checkpoint, use_fast=True)

if tokenizer.pad_token is None:
    tokenizer.pad_token = tokenizer.eos_token
    model.resize_token_embeddings(len(tokenizer))

model.config.pad_token_id = tokenizer.pad_token_id
model.config.use_cache = False

MAX_LEN = 128  


def clean_text(s):
    if s is None:
        return ""
    return " ".join(str(s).strip().split())


def tokenize_function(examples):

    texts = [
        f"Review: {clean_text(x)}\nSentiment:"
        for x in examples["sentence"]
    ]

    return tokenizer(
        texts,
        truncation=True,
        padding=False,   
        max_length=MAX_LEN,
    )


tokenized_dataset = dataset.map(
    tokenize_function,
    batched=True,
    remove_columns=["sentence", "idx"],
)

if "label" in tokenized_dataset["train"].column_names:
    tokenized_dataset = tokenized_dataset.rename_column("label", "labels")

tokenized_dataset.set_format("torch")


data_collator = DataCollatorWithPadding(
    tokenizer=tokenizer,
    pad_to_multiple_of=8,  
)
# Out:
# Map:   0%|          | 0/872 [00:00<?, ? examples/s]

# %%
accuracy = evaluate.load("accuracy")
rank = 6
def compute_metrics(eval_pred):
    preds, labels = eval_pred
    preds = np.argmax(preds, axis=1)
    return {"accuracy": accuracy.compute(predictions=preds, references=labels)}

peft_config = LoraConfig(
    task_type="SEQ_CLS",
    r=rank,
    lora_alpha=32,
    lora_dropout=0.05,
    target_modules=[   
        "q_proj", "k_proj", "v_proj", "o_proj", 
        "gate_proj", "up_proj", "down_proj"
    ]
)
model = get_peft_model(model, peft_config)

# %%
from peft.tuners.lora import LoraLayer

def get_lora_module_names(peft_model):
    names = []
    for name, module in peft_model.named_modules():
        if isinstance(module, LoraLayer):
            names.append(name)
    return names

lora_names = get_lora_module_names(model)   
print(f"🔢 Number of LoRA modules: {len(lora_names)}\n")

num_lora_modules = len(lora_names)
TOTAL_RANK_BUDGET = num_lora_modules*rank  

avg_rank_per_module = TOTAL_RANK_BUDGET / num_lora_modules
print(
    f" With TOTAL_RANK_BUDGET={TOTAL_RANK_BUDGET} over"
    f"{num_lora_modules} modules, avg rank ≈ {avg_rank_per_module:.2f}"
)
# Out:
# 🔢 Number of LoRA modules: 154
#
#  With TOTAL_RANK_BUDGET=924 over154 modules, avg rank ≈ 6.00

# %%
training_args = TrainingArguments(
    disable_tqdm=False,
    output_dir="./SST2_adaptive_results",
    num_train_epochs=3,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=8,
    logging_steps=500,
    eval_strategy="epoch",
    eval_steps=500,
    bf16=True,              
    report_to="none",
    save_strategy="no",
)

# %%
tokenized_dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['labels', 'input_ids', 'attention_mask'],
#         num_rows: 67349
#     })
#     validation: Dataset({
#         features: ['labels', 'input_ids', 'attention_mask'],
#         num_rows: 872
#     })
#     test: Dataset({
#         features: ['labels', 'input_ids', 'attention_mask'],
#         num_rows: 1821
#     })
# })

# %%
from torch.utils.data import DataLoader
train_dataset = tokenized_dataset["train"].select(range(10000))
eval_dataset = tokenized_dataset["validation"]

val_dataloader = DataLoader(
    eval_dataset,
    batch_size=8,
    shuffle=False,
    collate_fn=data_collator
)

# %%
from adaptive_lora.callbacks import AdaptiveLoRACallback

adaptive_callback = AdaptiveLoRACallback(
    val_dataloader=val_dataloader,
    total_rank=TOTAL_RANK_BUDGET,
    tau=0.9,      
    verbose=True
)

# %%
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=eval_dataset,
    tokenizer=tokenizer,
    data_collator=data_collator,
    compute_metrics=compute_metrics,
    callbacks=[adaptive_callback],
)

# %%
trainer.train()
# Out:
# --- AdaptiveLoRA: Preparing ranks for Epoch 1 ---
# Computing BI importance scores (pre-training)...
# Computing BI scores:   0%|          | 0/109 [00:00<?, ?it/s]
# Allocating new ranks based on BI scores...
# Applying new ranks to LoRA modules for this epoch...
#   - base_model.model.model.layers.0.self_attn.q_proj: r=6 (Unchanged, Score: 0.9897)
#   - base_model.model.model.layers.0.self_attn.k_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.0.self_attn.v_proj: r=6 (Unchanged, Score: 0.9963)
#   - base_model.model.model.layers.0.self_attn.o_proj: r=6 (Unchanged, Score: 0.9941)
#   - base_model.model.model.layers.0.mlp.gate_proj: r=6 (Unchanged, Score: 0.9943)
#   - base_model.model.model.layers.0.mlp.up_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.0.mlp.down_proj: r=6 (Unchanged, Score: 0.9992)
#   - base_model.model.model.layers.1.self_attn.q_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.1.self_attn.k_proj: r=6 (Unchanged, Score: 0.9921)
#   - base_model.model.model.layers.1.self_attn.v_proj: r=6 (Unchanged, Score: 0.9870)
#   - base_model.model.model.layers.1.self_attn.o_proj: r=6 (Unchanged, Score: 0.9830)
#   - base_model.model.model.layers.1.mlp.gate_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.1.mlp.up_proj: r=6 (Unchanged, Score: 0.9992)
#   - base_model.model.model.layers.1.mlp.down_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.2.self_attn.q_proj: r=6 (Unchanged, Score: 0.9917)
#   - base_model.model.model.layers.2.self_attn.k_proj: r=6 (Unchanged, Score: 0.9992)
#   - base_model.model.model.layers.2.self_attn.v_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.2.self_attn.o_proj: r=6 (Unchanged, Score: 0.9896)
#   - base_model.model.model.layers.2.mlp.gate_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.2.mlp.up_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.2.mlp.down_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.3.self_attn.q_proj: r=6 (Unchanged, Score: 0.9885)
#   - base_model.model.model.layers.3.self_attn.k_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.3.self_attn.v_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.3.self_attn.o_proj: r=6 (Unchanged, Score: 0.9948)
#   - base_model.model.model.layers.3.mlp.gate_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.3.mlp.up_proj: r=6 (Unchanged, Score: 0.9900)
#   - base_model.model.model.layers.3.mlp.down_proj: r=6 (Unchanged, Score: 0.9971)
#   - base_model.model.model.layers.4.self_attn.q_proj: r=6 (Unchanged, Score: 0.9895)
#   - base_model.model.model.layers.4.self_attn.k_proj: r=6 (Unchanged, Score: 0.9856)
#   - base_model.model.model.layers.4.self_attn.v_proj: r=6 (Unchanged, Score: 0.9861)
#   - base_model.model.model.layers.4.self_attn.o_proj: r=6 (Unchanged, Score: 0.9934)
#   - base_model.model.model.layers.4.mlp.gate_proj: r=6 (Unchanged, Score: 0.9897)
#   - base_model.model.model.layers.4.mlp.up_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.4.mlp.down_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.5.self_attn.q_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.5.self_attn.k_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.5.self_attn.v_proj: r=6 (Unchanged, Score: 0.9985)
#   - base_model.model.model.layers.5.self_attn.o_proj: r=6 (Unchanged, Score: 0.9983)
#   - base_model.model.model.layers.5.mlp.gate_proj: r=6 (Unchanged, Score: 0.9946)
#   - base_model.model.model.layers.5.mlp.up_proj: r=6 (Unchanged, Score: 0.9946)
#   - base_model.model.model.layers.5.mlp.down_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.6.self_attn.q_proj: r=6 (Unchanged, Score: 0.9862)
#   - base_model.model.model.layers.6.self_attn.k_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.6.self_attn.v_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.6.self_attn.o_proj: r=6 (Unchanged, Score: 0.9886)
#   - base_model.model.model.layers.6.mlp.gate_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.6.mlp.up_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.6.mlp.down_proj: r=6 (Unchanged, Score: 0.9985)
#   - base_model.model.model.layers.7.self_attn.q_proj: r=6 (Unchanged, Score: 0.9907)
#   - base_model.model.model.layers.7.self_attn.k_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.7.self_attn.v_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.7.self_attn.o_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.7.mlp.gate_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.7.mlp.up_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.7.mlp.down_proj: r=6 (Unchanged, Score: 0.9837)
#   - base_model.model.model.layers.8.self_attn.q_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.8.self_attn.k_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.8.self_attn.v_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.8.self_attn.o_proj: r=6 → 5 (Score: 0.9652)
#   - base_model.model.model.layers.8.mlp.gate_proj: r=6 (Unchanged, Score: 0.9876)
#   - base_model.model.model.layers.8.mlp.up_proj: r=6 (Unchanged, Score: 0.9972)
#   - base_model.model.model.layers.8.mlp.down_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.9.self_attn.q_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.9.self_attn.k_proj: r=6 → 4 (Score: 0.9550)
#   - base_model.model.model.layers.9.self_attn.v_proj: r=6 (Unchanged, Score: 0.9919)
#   - base_model.model.model.layers.9.self_attn.o_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.9.mlp.gate_proj: r=6 (Unchanged, Score: 0.9922)
#   - base_model.model.model.layers.9.mlp.up_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.9.mlp.down_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.10.self_attn.q_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.10.self_attn.k_proj: r=6 (Unchanged, Score: 0.9935)
#   - base_model.model.model.layers.10.self_attn.v_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.10.self_attn.o_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.10.mlp.gate_proj: r=6 (Unchanged, Score: 0.9988)
#   - base_model.model.model.layers.10.mlp.up_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.10.mlp.down_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.11.self_attn.q_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.11.self_attn.k_proj: r=6 (Unchanged, Score: 0.9949)
#   - base_model.model.model.layers.11.self_attn.v_proj: r=6 (Unchanged, Score: 0.9994)
#   - base_model.model.model.layers.11.self_attn.o_proj: r=6 (Unchanged, Score: 0.9920)
#   - base_model.model.model.layers.11.mlp.gate_proj: r=6 (Unchanged, Score: 0.9947)
#   - base_model.model.model.layers.11.mlp.up_proj: r=6 (Unchanged, Score: 0.9998)
#   - base_model.model.model.layers.11.mlp.down_proj: r=6 → 7 (Score: 1.0000)
#   - base_model.model.model.layers.12.self_attn.q_proj: r=6 → 7 (Score: 1.0000)
#   - base_model.model.model.layers.12.self_attn.k_proj: r=6 → 4 (Score: 0.8948)
#   - base_model.model.model.layers.12.self_attn.v_proj: r=6 → 5 (Score: 0.9767)
#   - base_model.model.model.layers.12.self_attn.o_proj: r=6 (Unchanged, Score: 0.9891)
#   - base_model.model.model.layers.12.mlp.gate_proj: r=6 (Unchanged, Score: 0.9979)
#   - base_model.model.model.layers.12.mlp.up_proj: r=6 (Unchanged, Score: 0.9999)
#   - base_model.model.model.layers.12.mlp.down_proj: r=6 (Unchanged, Score: 0.9946)
#   - base_model.model.model.layers.13.self_attn.q_proj: r=6 → 7 (Score: 1.0000)
#   - base_model.model.model.layers.13.self_attn.k_proj: r=6 → 4 (Score: 0.8838)
#   - base_model.model.model.layers.13.self_attn.v_proj: r=6 → 7 (Score: 1.0000)
#   - base_model.model.model.layers.13.self_attn.o_proj: r=6 (Unchanged, Score: 0.9847)
#   - base_model.model.model.layers.13.mlp.gate_proj: r=6 (Unchanged, Score: 0.9869)
#   - base_model.model.model.layers.13.mlp.up_proj: r=6 → 7 (Score: 1.0000)
#   - base_model.model.model.layers.13.mlp.down_proj: r=6 (Unchanged, Score: 0.9949)
#   - base_model.model.model.layers.14.self_attn.q_proj: r=6 → 7 (Score: 1.0000)
#   - base_model.model.model.layers.14.self_attn.k_proj: r=6 (Unchanged, Score: 0.9835)
#   - base_model.model.model.layers.14.self_attn.v_proj: r=6 → 7 (Score: 1.0000)
#   - base_model.model.model.layers.14.self_attn.o_proj: r=6 (Unchanged, Score: 0.9893)
#   - base_model.model.model.layers.14.mlp.gate_proj: r=6 (Unchanged, Score: 0.9868)
#   - base_model.model.model.layers.14.mlp.up_proj: r=6 → 7 (Score: 1.0000)
#   - base_model.model.model.layers.14.mlp.down_proj: r=6 → 7 (Score: 1.0000)
#   - base_model.model.model.layers.15.self_attn.q_proj: r=6 → 7 (Score: 1.0000)
#   - base_model.model.model.layers.15.self_attn.k_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.15.self_attn.v_proj: r=6 → 5 (Score: 0.9694)
#   - base_model.model.model.layers.15.self_attn.o_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.15.mlp.gate_proj: r=6 (Unchanged, Score: 0.9969)
#   - base_model.model.model.layers.15.mlp.up_proj: r=6 (Unchanged, Score: 0.9902)
#   - base_model.model.model.layers.15.mlp.down_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.16.self_attn.q_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.16.self_attn.k_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.16.self_attn.v_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.16.self_attn.o_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.16.mlp.gate_proj: r=6 (Unchanged, Score: 0.9881)
#   - base_model.model.model.layers.16.mlp.up_proj: r=6 (Unchanged, Score: 0.9917)
#   - base_model.model.model.layers.16.mlp.down_proj: r=6 → 7 (Score: 1.0000)
#   - base_model.model.model.layers.17.self_attn.q_proj: r=6 → 5 (Score: 0.9727)
#   - base_model.model.model.layers.17.self_attn.k_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.17.self_attn.v_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.17.self_attn.o_proj: r=6 (Unchanged, Score: 0.9976)
#   - base_model.model.model.layers.17.mlp.gate_proj: r=6 (Unchanged, Score: 0.9914)
#   - base_model.model.model.layers.17.mlp.up_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.17.mlp.down_proj: r=6 (Unchanged, Score: 0.9959)
#   - base_model.model.model.layers.18.self_attn.q_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.18.self_attn.k_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.18.self_attn.v_proj: r=6 (Unchanged, Score: 0.9995)
#   - base_model.model.model.layers.18.self_attn.o_proj: r=6 (Unchanged, Score: 0.9990)
#   - base_model.model.model.layers.18.mlp.gate_proj: r=6 → 7 (Score: 1.0000)
#   - base_model.model.model.layers.18.mlp.up_proj: r=6 (Unchanged, Score: 0.9842)
#   - base_model.model.model.layers.18.mlp.down_proj: r=6 (Unchanged, Score: 0.9978)
#   - base_model.model.model.layers.19.self_attn.q_proj: r=6 → 7 (Score: 1.0000)
#   - base_model.model.model.layers.19.self_attn.k_proj: r=6 → 4 (Score: 0.9466)
#   - base_model.model.model.layers.19.self_attn.v_proj: r=6 → 5 (Score: 0.9779)
#   - base_model.model.model.layers.19.self_attn.o_proj: r=6 (Unchanged, Score: 0.9847)
#   - base_model.model.model.layers.19.mlp.gate_proj: r=6 (Unchanged, Score: 0.9826)
#   - base_model.model.model.layers.19.mlp.up_proj: r=6 → 7 (Score: 1.0000)
#   - base_model.model.model.layers.19.mlp.down_proj: r=6 → 7 (Score: 1.0000)
#   - base_model.model.model.layers.20.self_attn.q_proj: r=6 → 5 (Score: 0.9780)
#   - base_model.model.model.layers.20.self_attn.k_proj: r=6 → 7 (Score: 1.0000)
#   - base_model.model.model.layers.20.self_attn.v_proj: r=6 → 7 (Score: 1.0000)
#   - base_model.model.model.layers.20.self_attn.o_proj: r=6 (Unchanged, Score: 0.9969)
#   - base_model.model.model.layers.20.mlp.gate_proj: r=6 (Unchanged, Score: 0.9964)
#   - base_model.model.model.layers.20.mlp.up_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.20.mlp.down_proj: r=6 (Unchanged, Score: 0.9936)
#   - base_model.model.model.layers.21.self_attn.q_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.21.self_attn.k_proj: r=6 → 5 (Score: 0.9819)
#   - base_model.model.model.layers.21.self_attn.v_proj: r=6 → 5 (Score: 0.9673)
#   - base_model.model.model.layers.21.self_attn.o_proj: r=6 (Unchanged, Score: 0.9944)
#   - base_model.model.model.layers.21.mlp.gate_proj: r=6 → 7 (Score: 1.0000)
#   - base_model.model.model.layers.21.mlp.up_proj: r=6 → 7 (Score: 1.0000)
#   - base_model.model.model.layers.21.mlp.down_proj: r=6 → 7 (Score: 1.0000)
# ✅ AdaptiveLoRA: Rank setup for Epoch 1 complete.
#     <div>
#
#       <progress value='1875' max='1875' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1875/1875 55:10, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.231100</td>
#       <td>0.238146</td>
#       <td>{'accuracy': 0.9438073394495413}</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.155200</td>
#       <td>0.242103</td>
#       <td>{'accuracy': 0.948394495412844}</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.122100</td>
#       <td>0.325530</td>
#       <td>{'accuracy': 0.9426605504587156}</td>
#     </tr>
#   </tbody>
# </table><p>
# 📄 Epoch 1: Rank allocations logged to ./logs/adaptive_lora_epoch_logs.csv
#
#
# --- AdaptiveLoRA: Preparing ranks for Epoch 2 ---
# Computing BI importance scores (pre-training)...
# Computing BI scores:   0%|          | 0/109 [00:00<?, ?it/s]
# Allocating new ranks based on BI scores...
# Applying new ranks to LoRA modules for this epoch...
#   - base_model.model.model.layers.0.self_attn.q_proj: r=6 (Unchanged, Score: 0.9897)
#   - base_model.model.model.layers.0.self_attn.k_proj: r=6 → 7 (Score: 1.0000)
#   - base_model.model.model.layers.0.self_attn.v_proj: r=6 (Unchanged, Score: 0.9989)
#   - base_model.model.model.layers.0.self_attn.o_proj: r=6 (Unchanged, Score: 0.9886)
#   - base_model.model.model.layers.0.mlp.gate_proj: r=6 (Unchanged, Score: 0.9934)
#   - base_model.model.model.layers.0.mlp.up_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.0.mlp.down_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.1.self_attn.q_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.1.self_attn.k_proj: r=6 (Unchanged, Score: 0.9936)
#   - base_model.model.model.layers.1.self_attn.v_proj: r=6 (Unchanged, Score: 0.9888)
#   - base_model.model.model.layers.1.self_attn.o_proj: r=6 (Unchanged, Score: 0.9899)
#   - base_model.model.model.layers.1.mlp.gate_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.1.mlp.up_proj: r=6 (Unchanged, Score: 0.9982)
#   - base_model.model.model.layers.1.mlp.down_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.2.self_attn.q_proj: r=6 (Unchanged, Score: 0.9928)
#   - base_model.model.model.layers.2.self_attn.k_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.2.self_attn.v_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.2.self_attn.o_proj: r=6 (Unchanged, Score: 0.9856)
#   - base_model.model.model.layers.2.mlp.gate_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.2.mlp.up_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.2.mlp.down_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.3.self_attn.q_proj: r=6 (Unchanged, Score: 0.9886)
#   - base_model.model.model.layers.3.self_attn.k_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.3.self_attn.v_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.3.self_attn.o_proj: r=6 (Unchanged, Score: 0.9886)
#   - base_model.model.model.layers.3.mlp.gate_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.3.mlp.up_proj: r=6 (Unchanged, Score: 0.9885)
#   - base_model.model.model.layers.3.mlp.down_proj: r=6 (Unchanged, Score: 0.9989)
#   - base_model.model.model.layers.4.self_attn.q_proj: r=6 (Unchanged, Score: 0.9943)
#   - base_model.model.model.layers.4.self_attn.k_proj: r=6 (Unchanged, Score: 0.9914)
#   - base_model.model.model.layers.4.self_attn.v_proj: r=6 (Unchanged, Score: 0.9976)
#   - base_model.model.model.layers.4.self_attn.o_proj: r=6 (Unchanged, Score: 0.9909)
#   - base_model.model.model.layers.4.mlp.gate_proj: r=6 (Unchanged, Score: 0.9910)
#   - base_model.model.model.layers.4.mlp.up_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.4.mlp.down_proj: r=6 (Unchanged, Score: 0.9986)
#   - base_model.model.model.layers.5.self_attn.q_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.5.self_attn.k_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.5.self_attn.v_proj: r=6 (Unchanged, Score: 0.9943)
#   - base_model.model.model.layers.5.self_attn.o_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.5.mlp.gate_proj: r=6 (Unchanged, Score: 0.9937)
#   - base_model.model.model.layers.5.mlp.up_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.5.mlp.down_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.6.self_attn.q_proj: r=6 (Unchanged, Score: 0.9859)
#   - base_model.model.model.layers.6.self_attn.k_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.6.self_attn.v_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.6.self_attn.o_proj: r=6 (Unchanged, Score: 0.9835)
#   - base_model.model.model.layers.6.mlp.gate_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.6.mlp.up_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.6.mlp.down_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.7.self_attn.q_proj: r=6 (Unchanged, Score: 0.9936)
#   - base_model.model.model.layers.7.self_attn.k_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.7.self_attn.v_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.7.self_attn.o_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.7.mlp.gate_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.7.mlp.up_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.7.mlp.down_proj: r=6 (Unchanged, Score: 0.9883)
#   - base_model.model.model.layers.8.self_attn.q_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.8.self_attn.k_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.8.self_attn.v_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.8.self_attn.o_proj: r=5 (Unchanged, Score: 0.9662)
#   - base_model.model.model.layers.8.mlp.gate_proj: r=6 (Unchanged, Score: 0.9903)
#   - base_model.model.model.layers.8.mlp.up_proj: r=6 (Unchanged, Score: 0.9965)
#   - base_model.model.model.layers.8.mlp.down_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.9.self_attn.q_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.9.self_attn.k_proj: r=4 (Unchanged, Score: 0.9365)
#   - base_model.model.model.layers.9.self_attn.v_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.9.self_attn.o_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.9.mlp.gate_proj: r=6 (Unchanged, Score: 0.9954)
#   - base_model.model.model.layers.9.mlp.up_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.9.mlp.down_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.10.self_attn.q_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.10.self_attn.k_proj: r=6 (Unchanged, Score: 0.9977)
#   - base_model.model.model.layers.10.self_attn.v_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.10.self_attn.o_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.10.mlp.gate_proj: r=6 (Unchanged, Score: 0.9983)
#   - base_model.model.model.layers.10.mlp.up_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.10.mlp.down_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.11.self_attn.q_proj: r=6 (Unchanged, Score: 0.9994)
#   - base_model.model.model.layers.11.self_attn.k_proj: r=6 (Unchanged, Score: 0.9844)
#   - base_model.model.model.layers.11.self_attn.v_proj: r=6 → 5 (Score: 0.9803)
#   - base_model.model.model.layers.11.self_attn.o_proj: r=6 (Unchanged, Score: 0.9954)
#   - base_model.model.model.layers.11.mlp.gate_proj: r=6 (Unchanged, Score: 0.9987)
#   - base_model.model.model.layers.11.mlp.up_proj: r=6 (Unchanged, Score: 0.9970)
#   - base_model.model.model.layers.11.mlp.down_proj: r=7 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.12.self_attn.q_proj: r=7 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.12.self_attn.k_proj: r=4 (Unchanged, Score: 0.8993)
#   - base_model.model.model.layers.12.self_attn.v_proj: r=5 (Unchanged, Score: 0.9748)
#   - base_model.model.model.layers.12.self_attn.o_proj: r=6 (Unchanged, Score: 0.9880)
#   - base_model.model.model.layers.12.mlp.gate_proj: r=6 (Unchanged, Score: 0.9957)
#   - base_model.model.model.layers.12.mlp.up_proj: r=6 → 7 (Score: 1.0000)
#   - base_model.model.model.layers.12.mlp.down_proj: r=6 (Unchanged, Score: 0.9948)
#   - base_model.model.model.layers.13.self_attn.q_proj: r=7 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.13.self_attn.k_proj: r=4 (Unchanged, Score: 0.8732)
#   - base_model.model.model.layers.13.self_attn.v_proj: r=7 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.13.self_attn.o_proj: r=6 (Unchanged, Score: 0.9814)
#   - base_model.model.model.layers.13.mlp.gate_proj: r=6 (Unchanged, Score: 0.9863)
#   - base_model.model.model.layers.13.mlp.up_proj: r=7 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.13.mlp.down_proj: r=6 → 7 (Score: 1.0000)
#   - base_model.model.model.layers.14.self_attn.q_proj: r=7 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.14.self_attn.k_proj: r=6 → 5 (Score: 0.9800)
#   - base_model.model.model.layers.14.self_attn.v_proj: r=7 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.14.self_attn.o_proj: r=6 (Unchanged, Score: 0.9895)
#   - base_model.model.model.layers.14.mlp.gate_proj: r=6 (Unchanged, Score: 0.9864)
#   - base_model.model.model.layers.14.mlp.up_proj: r=7 → 6 (Score: 1.0000)
#   - base_model.model.model.layers.14.mlp.down_proj: r=7 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.15.self_attn.q_proj: r=7 → 6 (Score: 1.0000)
#   - base_model.model.model.layers.15.self_attn.k_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.15.self_attn.v_proj: r=5 (Unchanged, Score: 0.9752)
#   - base_model.model.model.layers.15.self_attn.o_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.15.mlp.gate_proj: r=6 (Unchanged, Score: 0.9982)
#   - base_model.model.model.layers.15.mlp.up_proj: r=6 (Unchanged, Score: 0.9929)
#   - base_model.model.model.layers.15.mlp.down_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.16.self_attn.q_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.16.self_attn.k_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.16.self_attn.v_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.16.self_attn.o_proj: r=6 → 7 (Score: 1.0000)
#   - base_model.model.model.layers.16.mlp.gate_proj: r=6 (Unchanged, Score: 0.9887)
#   - base_model.model.model.layers.16.mlp.up_proj: r=6 (Unchanged, Score: 0.9870)
#   - base_model.model.model.layers.16.mlp.down_proj: r=7 → 6 (Score: 1.0000)
#   - base_model.model.model.layers.17.self_attn.q_proj: r=5 (Unchanged, Score: 0.9741)
#   - base_model.model.model.layers.17.self_attn.k_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.17.self_attn.v_proj: r=6 (Unchanged, Score: 0.9970)
#   - base_model.model.model.layers.17.self_attn.o_proj: r=6 (Unchanged, Score: 0.9989)
#   - base_model.model.model.layers.17.mlp.gate_proj: r=6 (Unchanged, Score: 0.9982)
#   - base_model.model.model.layers.17.mlp.up_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.17.mlp.down_proj: r=6 (Unchanged, Score: 0.9979)
#   - base_model.model.model.layers.18.self_attn.q_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.18.self_attn.k_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.18.self_attn.v_proj: r=6 (Unchanged, Score: 0.9909)
#   - base_model.model.model.layers.18.self_attn.o_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.18.mlp.gate_proj: r=7 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.18.mlp.up_proj: r=6 (Unchanged, Score: 0.9843)
#   - base_model.model.model.layers.18.mlp.down_proj: r=6 (Unchanged, Score: 0.9975)
#   - base_model.model.model.layers.19.self_attn.q_proj: r=7 → 6 (Score: 1.0000)
#   - base_model.model.model.layers.19.self_attn.k_proj: r=4 (Unchanged, Score: 0.9456)
#   - base_model.model.model.layers.19.self_attn.v_proj: r=5 (Unchanged, Score: 0.9713)
#   - base_model.model.model.layers.19.self_attn.o_proj: r=6 (Unchanged, Score: 0.9868)
#   - base_model.model.model.layers.19.mlp.gate_proj: r=6 (Unchanged, Score: 0.9808)
#   - base_model.model.model.layers.19.mlp.up_proj: r=7 → 6 (Score: 1.0000)
#   - base_model.model.model.layers.19.mlp.down_proj: r=7 → 6 (Score: 1.0000)
#   - base_model.model.model.layers.20.self_attn.q_proj: r=5 → 6 (Score: 0.9814)
#   - base_model.model.model.layers.20.self_attn.k_proj: r=7 → 6 (Score: 0.9991)
#   - base_model.model.model.layers.20.self_attn.v_proj: r=7 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.20.self_attn.o_proj: r=6 (Unchanged, Score: 0.9977)
#   - base_model.model.model.layers.20.mlp.gate_proj: r=6 (Unchanged, Score: 0.9963)
#   - base_model.model.model.layers.20.mlp.up_proj: r=6 → 7 (Score: 1.0000)
#   - base_model.model.model.layers.20.mlp.down_proj: r=6 (Unchanged, Score: 0.9944)
#   - base_model.model.model.layers.21.self_attn.q_proj: r=6 → 7 (Score: 1.0000)
#   - base_model.model.model.layers.21.self_attn.k_proj: r=5 → 6 (Score: 0.9821)
#   - base_model.model.model.layers.21.self_attn.v_proj: r=5 (Unchanged, Score: 0.9677)
#   - base_model.model.model.layers.21.self_attn.o_proj: r=6 (Unchanged, Score: 0.9970)
#   - base_model.model.model.layers.21.mlp.gate_proj: r=7 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.21.mlp.up_proj: r=7 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.21.mlp.down_proj: r=7 (Unchanged, Score: 1.0000)
# ✅ AdaptiveLoRA: Rank setup for Epoch 2 complete.
#
# 📄 Epoch 2: Rank allocations logged to ./logs/adaptive_lora_epoch_logs.csv
#
#
# --- AdaptiveLoRA: Preparing ranks for Epoch 3 ---
# Computing BI importance scores (pre-training)...
# Computing BI scores:   0%|          | 0/109 [00:00<?, ?it/s]
# Allocating new ranks based on BI scores...
# Applying new ranks to LoRA modules for this epoch...
#   - base_model.model.model.layers.0.self_attn.q_proj: r=6 (Unchanged, Score: 0.9897)
#   - base_model.model.model.layers.0.self_attn.k_proj: r=7 → 6 (Score: 1.0000)
#   - base_model.model.model.layers.0.self_attn.v_proj: r=6 (Unchanged, Score: 0.9997)
#   - base_model.model.model.layers.0.self_attn.o_proj: r=6 (Unchanged, Score: 0.9883)
#   - base_model.model.model.layers.0.mlp.gate_proj: r=6 (Unchanged, Score: 0.9928)
#   - base_model.model.model.layers.0.mlp.up_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.0.mlp.down_proj: r=6 (Unchanged, Score: 0.9994)
#   - base_model.model.model.layers.1.self_attn.q_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.1.self_attn.k_proj: r=6 (Unchanged, Score: 0.9930)
#   - base_model.model.model.layers.1.self_attn.v_proj: r=6 (Unchanged, Score: 0.9906)
#   - base_model.model.model.layers.1.self_attn.o_proj: r=6 (Unchanged, Score: 0.9929)
#   - base_model.model.model.layers.1.mlp.gate_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.1.mlp.up_proj: r=6 (Unchanged, Score: 0.9991)
#   - base_model.model.model.layers.1.mlp.down_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.2.self_attn.q_proj: r=6 (Unchanged, Score: 0.9932)
#   - base_model.model.model.layers.2.self_attn.k_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.2.self_attn.v_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.2.self_attn.o_proj: r=6 (Unchanged, Score: 0.9839)
#   - base_model.model.model.layers.2.mlp.gate_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.2.mlp.up_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.2.mlp.down_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.3.self_attn.q_proj: r=6 (Unchanged, Score: 0.9888)
#   - base_model.model.model.layers.3.self_attn.k_proj: r=6 (Unchanged, Score: 0.9992)
#   - base_model.model.model.layers.3.self_attn.v_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.3.self_attn.o_proj: r=6 (Unchanged, Score: 0.9907)
#   - base_model.model.model.layers.3.mlp.gate_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.3.mlp.up_proj: r=6 (Unchanged, Score: 0.9905)
#   - base_model.model.model.layers.3.mlp.down_proj: r=6 (Unchanged, Score: 0.9970)
#   - base_model.model.model.layers.4.self_attn.q_proj: r=6 (Unchanged, Score: 0.9971)
#   - base_model.model.model.layers.4.self_attn.k_proj: r=6 (Unchanged, Score: 0.9912)
#   - base_model.model.model.layers.4.self_attn.v_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.4.self_attn.o_proj: r=6 (Unchanged, Score: 0.9935)
#   - base_model.model.model.layers.4.mlp.gate_proj: r=6 (Unchanged, Score: 0.9898)
#   - base_model.model.model.layers.4.mlp.up_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.4.mlp.down_proj: r=6 (Unchanged, Score: 0.9973)
#   - base_model.model.model.layers.5.self_attn.q_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.5.self_attn.k_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.5.self_attn.v_proj: r=6 (Unchanged, Score: 0.9955)
#   - base_model.model.model.layers.5.self_attn.o_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.5.mlp.gate_proj: r=6 (Unchanged, Score: 0.9929)
#   - base_model.model.model.layers.5.mlp.up_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.5.mlp.down_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.6.self_attn.q_proj: r=6 (Unchanged, Score: 0.9869)
#   - base_model.model.model.layers.6.self_attn.k_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.6.self_attn.v_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.6.self_attn.o_proj: r=6 (Unchanged, Score: 0.9832)
#   - base_model.model.model.layers.6.mlp.gate_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.6.mlp.up_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.6.mlp.down_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.7.self_attn.q_proj: r=6 (Unchanged, Score: 0.9933)
#   - base_model.model.model.layers.7.self_attn.k_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.7.self_attn.v_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.7.self_attn.o_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.7.mlp.gate_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.7.mlp.up_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.7.mlp.down_proj: r=6 (Unchanged, Score: 0.9887)
#   - base_model.model.model.layers.8.self_attn.q_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.8.self_attn.k_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.8.self_attn.v_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.8.self_attn.o_proj: r=5 (Unchanged, Score: 0.9685)
#   - base_model.model.model.layers.8.mlp.gate_proj: r=6 (Unchanged, Score: 0.9900)
#   - base_model.model.model.layers.8.mlp.up_proj: r=6 (Unchanged, Score: 0.9962)
#   - base_model.model.model.layers.8.mlp.down_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.9.self_attn.q_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.9.self_attn.k_proj: r=4 (Unchanged, Score: 0.9385)
#   - base_model.model.model.layers.9.self_attn.v_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.9.self_attn.o_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.9.mlp.gate_proj: r=6 (Unchanged, Score: 0.9946)
#   - base_model.model.model.layers.9.mlp.up_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.9.mlp.down_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.10.self_attn.q_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.10.self_attn.k_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.10.self_attn.v_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.10.self_attn.o_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.10.mlp.gate_proj: r=6 (Unchanged, Score: 0.9989)
#   - base_model.model.model.layers.10.mlp.up_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.10.mlp.down_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.11.self_attn.q_proj: r=6 (Unchanged, Score: 0.9997)
#   - base_model.model.model.layers.11.self_attn.k_proj: r=6 (Unchanged, Score: 0.9862)
#   - base_model.model.model.layers.11.self_attn.v_proj: r=5 → 6 (Score: 0.9844)
#   - base_model.model.model.layers.11.self_attn.o_proj: r=6 (Unchanged, Score: 0.9958)
#   - base_model.model.model.layers.11.mlp.gate_proj: r=6 (Unchanged, Score: 0.9983)
#   - base_model.model.model.layers.11.mlp.up_proj: r=6 (Unchanged, Score: 0.9978)
#   - base_model.model.model.layers.11.mlp.down_proj: r=7 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.12.self_attn.q_proj: r=7 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.12.self_attn.k_proj: r=4 (Unchanged, Score: 0.9046)
#   - base_model.model.model.layers.12.self_attn.v_proj: r=5 (Unchanged, Score: 0.9722)
#   - base_model.model.model.layers.12.self_attn.o_proj: r=6 (Unchanged, Score: 0.9883)
#   - base_model.model.model.layers.12.mlp.gate_proj: r=6 (Unchanged, Score: 0.9950)
#   - base_model.model.model.layers.12.mlp.up_proj: r=7 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.12.mlp.down_proj: r=6 (Unchanged, Score: 0.9956)
#   - base_model.model.model.layers.13.self_attn.q_proj: r=7 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.13.self_attn.k_proj: r=4 (Unchanged, Score: 0.8769)
#   - base_model.model.model.layers.13.self_attn.v_proj: r=7 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.13.self_attn.o_proj: r=6 (Unchanged, Score: 0.9821)
#   - base_model.model.model.layers.13.mlp.gate_proj: r=6 (Unchanged, Score: 0.9870)
#   - base_model.model.model.layers.13.mlp.up_proj: r=7 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.13.mlp.down_proj: r=7 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.14.self_attn.q_proj: r=7 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.14.self_attn.k_proj: r=5 (Unchanged, Score: 0.9767)
#   - base_model.model.model.layers.14.self_attn.v_proj: r=7 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.14.self_attn.o_proj: r=6 (Unchanged, Score: 0.9902)
#   - base_model.model.model.layers.14.mlp.gate_proj: r=6 (Unchanged, Score: 0.9878)
#   - base_model.model.model.layers.14.mlp.up_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.14.mlp.down_proj: r=7 → 6 (Score: 1.0000)
#   - base_model.model.model.layers.15.self_attn.q_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.15.self_attn.k_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.15.self_attn.v_proj: r=5 (Unchanged, Score: 0.9776)
#   - base_model.model.model.layers.15.self_attn.o_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.15.mlp.gate_proj: r=6 (Unchanged, Score: 0.9973)
#   - base_model.model.model.layers.15.mlp.up_proj: r=6 (Unchanged, Score: 0.9935)
#   - base_model.model.model.layers.15.mlp.down_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.16.self_attn.q_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.16.self_attn.k_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.16.self_attn.v_proj: r=6 → 7 (Score: 1.0000)
#   - base_model.model.model.layers.16.self_attn.o_proj: r=7 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.16.mlp.gate_proj: r=6 (Unchanged, Score: 0.9895)
#   - base_model.model.model.layers.16.mlp.up_proj: r=6 (Unchanged, Score: 0.9872)
#   - base_model.model.model.layers.16.mlp.down_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.17.self_attn.q_proj: r=5 (Unchanged, Score: 0.9753)
#   - base_model.model.model.layers.17.self_attn.k_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.17.self_attn.v_proj: r=6 (Unchanged, Score: 0.9975)
#   - base_model.model.model.layers.17.self_attn.o_proj: r=6 (Unchanged, Score: 0.9991)
#   - base_model.model.model.layers.17.mlp.gate_proj: r=6 (Unchanged, Score: 0.9978)
#   - base_model.model.model.layers.17.mlp.up_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.17.mlp.down_proj: r=6 (Unchanged, Score: 0.9985)
#   - base_model.model.model.layers.18.self_attn.q_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.18.self_attn.k_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.18.self_attn.v_proj: r=6 (Unchanged, Score: 0.9937)
#   - base_model.model.model.layers.18.self_attn.o_proj: r=6 (Unchanged, Score: 0.9996)
#   - base_model.model.model.layers.18.mlp.gate_proj: r=7 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.18.mlp.up_proj: r=6 (Unchanged, Score: 0.9842)
#   - base_model.model.model.layers.18.mlp.down_proj: r=6 (Unchanged, Score: 0.9971)
#   - base_model.model.model.layers.19.self_attn.q_proj: r=6 → 7 (Score: 1.0000)
#   - base_model.model.model.layers.19.self_attn.k_proj: r=4 (Unchanged, Score: 0.9453)
#   - base_model.model.model.layers.19.self_attn.v_proj: r=5 (Unchanged, Score: 0.9762)
#   - base_model.model.model.layers.19.self_attn.o_proj: r=6 (Unchanged, Score: 0.9878)
#   - base_model.model.model.layers.19.mlp.gate_proj: r=6 (Unchanged, Score: 0.9821)
#   - base_model.model.model.layers.19.mlp.up_proj: r=6 → 7 (Score: 1.0000)
#   - base_model.model.model.layers.19.mlp.down_proj: r=6 → 7 (Score: 1.0000)
#   - base_model.model.model.layers.20.self_attn.q_proj: r=6 → 5 (Score: 0.9809)
#   - base_model.model.model.layers.20.self_attn.k_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.20.self_attn.v_proj: r=7 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.20.self_attn.o_proj: r=6 (Unchanged, Score: 0.9977)
#   - base_model.model.model.layers.20.mlp.gate_proj: r=6 (Unchanged, Score: 0.9956)
#   - base_model.model.model.layers.20.mlp.up_proj: r=7 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.20.mlp.down_proj: r=6 (Unchanged, Score: 0.9949)
#   - base_model.model.model.layers.21.self_attn.q_proj: r=7 → 6 (Score: 1.0000)
#   - base_model.model.model.layers.21.self_attn.k_proj: r=6 → 5 (Score: 0.9809)
#   - base_model.model.model.layers.21.self_attn.v_proj: r=5 (Unchanged, Score: 0.9660)
#   - base_model.model.model.layers.21.self_attn.o_proj: r=6 (Unchanged, Score: 0.9976)
#   - base_model.model.model.layers.21.mlp.gate_proj: r=7 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.21.mlp.up_proj: r=7 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.21.mlp.down_proj: r=7 (Unchanged, Score: 1.0000)
# ✅ AdaptiveLoRA: Rank setup for Epoch 3 complete.
#
# 📄 Epoch 3: Rank allocations logged to ./logs/adaptive_lora_epoch_logs.csv
# TrainOutput(global_step=1875, training_loss=0.1506740997314453, metrics={'train_runtime': 3364.6706, 'train_samples_per_second': 8.916, 'train_steps_per_second': 0.557, 'total_flos': 8718560988168192.0, 'train_loss': 0.1506740997314453, 'epoch': 3.0})

# %%
met = trainer.evaluate()
print(met)
# Out:
#     <div>
#
#       <progress value='109' max='109' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [109/109 00:48]
#     </div>
# {'eval_loss': 0.32552972435951233, 'eval_accuracy': {'accuracy': 0.9426605504587156}, 'eval_runtime': 48.795, 'eval_samples_per_second': 17.871, 'eval_steps_per_second': 2.234, 'epoch': 3.0}
