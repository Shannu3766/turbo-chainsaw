# %%
# !pip install datasets
# !pip install transformers
# !pip install peft
# !pip install evaluate
# !pip install -U datasets==2.20.0 pyarrow==15.0.2 transformers==4.44.2 evaluate==0.4.2 --no-cache-dir
# !pip install -q datasets evaluate accelerate scikit-learn pandas matplotlib
# !pip install -U "transformers>=4.41" accelerate safetensors
# !pip install -U bitsandbytes

# !pip install -U evaluate
# Out:
# Collecting evaluate
#   Downloading evaluate-0.4.6-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: datasets>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from evaluate) (4.4.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from evaluate) (2.0.2)
# Requirement already satisfied: dill in /usr/local/lib/python3.12/dist-packages (from evaluate) (0.4.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from evaluate) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.12/dist-packages (from evaluate) (2.32.5)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.12/dist-packages (from evaluate) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from evaluate) (3.6.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.12/dist-packages (from evaluate) (0.70.18)
# Requirement already satisfied: fsspec>=2021.05.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]>=2021.05.0->evaluate) (2025.10.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from evaluate) (0.36.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from evaluate) (25.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets>=2.0.0->evaluate) (3.20.1)
# Requirement already satisfied: pyarrow>=21.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.0.0->evaluate) (22.0.0)
# Requirement already satisfied: httpx<1.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.0.0->evaluate) (0.28.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.0.0->evaluate) (6.0.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]>=2021.05.0->evaluate) (3.13.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.7.0->evaluate) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.7.0->evaluate) (1.2.1rc0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->evaluate) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->evaluate) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->evaluate) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->evaluate) (2025.11.12)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->evaluate) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->evaluate) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->evaluate) (2025.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.22.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets>=2.0.0->evaluate) (4.12.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets>=2.0.0->evaluate) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0.0->datasets>=2.0.0->evaluate) (0.16.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.17.0)
# Downloading evaluate-0.4.6-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 2.7 MB/s eta 0:00:00
# Installing collected packages: evaluate
# Successfully installed evaluate-0.4.6

# %%
# !pip install --upgrade --no-cache-dir git+https://github.com/Shannu3766/bi_influence.git@version_1
# Out:
# Collecting git+https://github.com/Shannu3766/bi_influence.git@version_1
#   Cloning https://github.com/Shannu3766/bi_influence.git (to revision version_1) to /tmp/pip-req-build-ycx_t97i
#   Running command git clone --filter=blob:none --quiet https://github.com/Shannu3766/bi_influence.git /tmp/pip-req-build-ycx_t97i
#   Running command git checkout -b version_1 --track origin/version_1
#   Switched to a new branch 'version_1'
#   Branch 'version_1' set up to track remote branch 'version_1' from 'origin'.
#   Resolved https://github.com/Shannu3766/bi_influence.git to commit 4dc6f1ccec6c2ed8210d2b8da51a42dd1172dce8
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch>=1.13 in /usr/local/lib/python3.12/dist-packages (from adaptive_lora==2.1.0) (2.8.0+cu126)
# Requirement already satisfied: transformers>=4.30 in /usr/local/lib/python3.12/dist-packages (from adaptive_lora==2.1.0) (4.57.1)
# Requirement already satisfied: peft>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from adaptive_lora==2.1.0) (0.17.1)
# Requirement already satisfied: datasets>=2.0 in /usr/local/lib/python3.12/dist-packages (from adaptive_lora==2.1.0) (4.4.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from adaptive_lora==2.1.0) (4.67.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from adaptive_lora==2.1.0) (2.0.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from adaptive_lora==2.1.0) (1.6.1)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.12/dist-packages (from adaptive_lora==2.1.0) (1.11.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from adaptive_lora==2.1.0) (2.2.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets>=2.0->adaptive_lora==2.1.0) (3.20.1)
# Requirement already satisfied: pyarrow>=21.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.0->adaptive_lora==2.1.0) (22.0.0)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.0->adaptive_lora==2.1.0) (0.4.0)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.0->adaptive_lora==2.1.0) (2.32.5)
# Requirement already satisfied: httpx<1.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.0->adaptive_lora==2.1.0) (0.28.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets>=2.0->adaptive_lora==2.1.0) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.19 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.0->adaptive_lora==2.1.0) (0.70.18)
# Requirement already satisfied: fsspec<=2025.10.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets>=2.0->adaptive_lora==2.1.0) (2025.10.0)
# Requirement already satisfied: huggingface-hub<2.0,>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.0->adaptive_lora==2.1.0) (0.36.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from datasets>=2.0->adaptive_lora==2.1.0) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.0->adaptive_lora==2.1.0) (6.0.3)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from peft>=0.3.0->adaptive_lora==2.1.0) (5.9.5)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.12/dist-packages (from peft>=0.3.0->adaptive_lora==2.1.0) (0.6.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->adaptive_lora==2.1.0) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->adaptive_lora==2.1.0) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->adaptive_lora==2.1.0) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->adaptive_lora==2.1.0) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->adaptive_lora==2.1.0) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->adaptive_lora==2.1.0) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->adaptive_lora==2.1.0) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->adaptive_lora==2.1.0) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->adaptive_lora==2.1.0) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->adaptive_lora==2.1.0) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->adaptive_lora==2.1.0) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->adaptive_lora==2.1.0) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->adaptive_lora==2.1.0) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->adaptive_lora==2.1.0) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->adaptive_lora==2.1.0) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->adaptive_lora==2.1.0) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->adaptive_lora==2.1.0) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->adaptive_lora==2.1.0) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->adaptive_lora==2.1.0) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->adaptive_lora==2.1.0) (3.4.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.30->adaptive_lora==2.1.0) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.30->adaptive_lora==2.1.0) (0.22.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->adaptive_lora==2.1.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->adaptive_lora==2.1.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->adaptive_lora==2.1.0) (2025.3)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->adaptive_lora==2.1.0) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->adaptive_lora==2.1.0) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->adaptive_lora==2.1.0) (3.6.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets>=2.0->adaptive_lora==2.1.0) (3.13.2)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets>=2.0->adaptive_lora==2.1.0) (4.12.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets>=2.0->adaptive_lora==2.1.0) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets>=2.0->adaptive_lora==2.1.0) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets>=2.0->adaptive_lora==2.1.0) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0.0->datasets>=2.0->adaptive_lora==2.1.0) (0.16.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.25.0->datasets>=2.0->adaptive_lora==2.1.0) (1.2.1rc0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->adaptive_lora==2.1.0) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets>=2.0->adaptive_lora==2.1.0) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets>=2.0->adaptive_lora==2.1.0) (2.6.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.13->adaptive_lora==2.1.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.13->adaptive_lora==2.1.0) (3.0.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets>=2.0->adaptive_lora==2.1.0) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets>=2.0->adaptive_lora==2.1.0) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets>=2.0->adaptive_lora==2.1.0) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets>=2.0->adaptive_lora==2.1.0) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets>=2.0->adaptive_lora==2.1.0) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets>=2.0->adaptive_lora==2.1.0) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets>=2.0->adaptive_lora==2.1.0) (1.22.0)
# Building wheels for collected packages: adaptive_lora
#   Building wheel for adaptive_lora (setup.py) ... done
#   Created wheel for adaptive_lora: filename=adaptive_lora-2.1.0-py3-none-any.whl size=5843 sha256=3b4f4b26a2b31ddc84af700280159ce73c4c7533b3060f7ab0f48f069d890562
#   Stored in directory: /tmp/pip-ephem-wheel-cache-zig4_ue7/wheels/8d/29/cf/be29446b489124e88897058c28dfe358ba113f9b57f04c0ba4
# Successfully built adaptive_lora
# Installing collected packages: adaptive_lora
# Successfully installed adaptive_lora-2.1.0

# %%
import os
from typing import Optional
from datasets import load_dataset
from transformers import (
    AutoTokenizer,
    AutoModelForSequenceClassification,
    TrainingArguments,
    Trainer,
    DataCollatorWithPadding,
)
from peft import LoraConfig, get_peft_model, TaskType
import evaluate
from adaptive_lora.callbacks import AdaptiveLoRACallback
# Out:
# 2025-12-17 20:11:28.445562: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1766002288.928546      24 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1766002289.050194      24 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1766002290.206478      24 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1766002290.206522      24 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1766002290.206524      24 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1766002290.206527      24 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.

# %%
import torch

# %%
model_checkpoint = "TinyLlama/TinyLlama-1.1B-Chat-v1.0" 
output_dir = "./tinyllama-qnli-lora"
seed = 42
device = "cuda" if torch.cuda.is_available() else "cpu"
print(device)
# Out:
# cuda

# %%
batch_size = 16
eval_batch_size = 32
num_train_epochs = 3
max_length = 128
learning_rate = 2e-5
weight_decay = 0.01
rank=6
peft_config = LoraConfig(
    task_type=TaskType.SEQ_CLS,
    r=rank,
    lora_alpha=32,
    lora_dropout=0.05,
    bias="none",
    target_modules=[   
        "q_proj", "k_proj", "v_proj", "o_proj", 
        "gate_proj", "up_proj", "down_proj"
    ],)

# %%
def clean_text(s: Optional[str]) -> str:
    if s is None:
        return ""
    return " ".join(str(s).strip().split())

def build_one_shot_demo(example: dict) -> str:
    q = clean_text(example["question"])
    c = clean_text(example["context"])
    lbl = example.get("label_text", "Yes")
    return f"Example:\nQuestion: {q}\nContext: {c}\nAnswer (Yes/No): {lbl}\n\n"

# %%
ONE_SHOT_EXAMPLE = {
    "question": "Who wrote Hamlet?",
    "context": "Hamlet was written by William Shakespeare and first performed in the early 17th century.",
    "label_text": "Yes",  # "Yes" => the context contains the answer
}

from datasets import load_dataset
import time

def load_dataset_with_retry(path, name=None, max_retries=None, wait=2):
    """
    Repeatedly tries to load a dataset until it succeeds.
    - max_retries: None → infinite retries
    - wait: base wait time (exponential backoff)
    """
    attempt = 0

    while True:
        try:
            if name is not None:
                ds = load_dataset(path, name)
            else:
                ds = load_dataset(path)

            print(f"Dataset loaded successfully after {attempt} attempts.")
            return ds

        except Exception as e:
            attempt += 1
            wait_time = wait * min(5, attempt)  # exponential cap

            print(f"[Attempt {attempt}] Failed to load dataset: {e}")
            print(f"Retrying in {wait_time} seconds...\n")

            # If user gives a max_retries limit
            if max_retries is not None and attempt >= max_retries:
                print("Max retries reached. Raising error.")
                raise e

            time.sleep(wait_time)
dataset = load_dataset_with_retry("glue", "qnli")
# dataset = load_dataset("glue", "qnli")
# Out:
# README.md: 0.00B [00:00, ?B/s]
# qnli/train-00000-of-00001.parquet:   0%|          | 0.00/17.5M [00:00<?, ?B/s]
# qnli/validation-00000-of-00001.parquet:   0%|          | 0.00/872k [00:00<?, ?B/s]
# qnli/test-00000-of-00001.parquet:   0%|          | 0.00/877k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/104743 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/5463 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/5463 [00:00<?, ? examples/s]
# Dataset loaded successfully after 0 attempts.

# %%
tokenizer = AutoTokenizer.from_pretrained(model_checkpoint, use_fast=True)

if tokenizer.pad_token is None:
    # safe default: use eos_token as pad
    tokenizer.pad_token = tokenizer.eos_token
# Out:
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/551 [00:00<?, ?B/s]

# %%
# Load tokenizer


def preprocess_function(examples, *, max_length: int = max_length, add_demo: bool = False):
    """
    Build instruction-like prompts and tokenize them.
    - add_demo: if True, prepends a 1-shot example to each prompt (can help decoder-only models)
    """
    questions = [clean_text(q) for q in examples["question"]]
    contexts = [clean_text(s) for s in examples["sentence"]]

    demo_str = build_one_shot_demo(ONE_SHOT_EXAMPLE) if add_demo else ""

    prompts = []
    for q, c in zip(questions, contexts):
        # Instruction-style prompt ending with a short, constrained label target
        prompt = (
            "You are a helpful assistant.\n"
            f"{demo_str}"
            f"Question: {q}\n"
            f"Context: {c}\n"
            "Answer (Yes/No):"
        )
        prompts.append(prompt)

    tokenized = tokenizer(
        prompts,
        truncation=True,
        max_length=max_length,
        padding=False, 
    )

    if "label" in examples:
        tokenized["labels"] = examples["label"]
    elif "labels" in examples:
        tokenized["labels"] = examples["labels"]

    return tokenized

print("Tokenizing dataset...")
tokenized = dataset.map(
    lambda ex: preprocess_function(ex, max_length=max_length, add_demo=False),
    batched=True,
    remove_columns=["question", "sentence", "idx"],
)

if "label" in tokenized["train"].column_names and "labels" not in tokenized["train"].column_names:
    tokenized = tokenized.rename_column("label", "labels")

tokenized.set_format(type="torch", columns=["input_ids", "attention_mask", "labels"])

data_collator = DataCollatorWithPadding(tokenizer=tokenizer, padding="longest", pad_to_multiple_of=8)
train_dataset = tokenized["train"].select(range(10000))
eval_dataset = tokenized["validation"].select(range(1500))
# Out:
# Tokenizing dataset...
# Map:   0%|          | 0/104743 [00:00<?, ? examples/s]
# Map:   0%|          | 0/5463 [00:00<?, ? examples/s]
# Map:   0%|          | 0/5463 [00:00<?, ? examples/s]

# %%
print("Loading model...")
model = AutoModelForSequenceClassification.from_pretrained(
    model_checkpoint,
    num_labels=2,
    device_map="auto",
    torch_dtype=torch.bfloat16, 
    trust_remote_code=True
)

print("Model Loaded")
# Out:
# Loading model...
# config.json:   0%|          | 0.00/608 [00:00<?, ?B/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors:   0%|          | 0.00/2.20G [00:00<?, ?B/s]
# Some weights of LlamaForSequenceClassification were not initialized from the model checkpoint at TinyLlama/TinyLlama-1.1B-Chat-v1.0 and are newly initialized: ['score.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Model Loaded

# %%
# Resize token embeddings if tokenizer changed
model.resize_token_embeddings(len(tokenizer))
model.config.pad_token_id = tokenizer.pad_token_id
model.config.use_cache = False

# -------------------------
# Apply LoRA (PEFT)
# -------------------------
print("Applying LoRA (PEFT)...")
model = get_peft_model(model, peft_config)
# Out:
# Applying LoRA (PEFT)...

# %%
val_dataloader = torch.utils.data.DataLoader(
    eval_dataset,
    batch_size=eval_batch_size,
    shuffle=False,
    collate_fn=data_collator,
    pin_memory=torch.cuda.is_available(),
    num_workers=2,
)

# %%
from peft.tuners.lora import LoraLayer

def get_lora_module_names(peft_model):
    names = []
    for name, module in peft_model.named_modules():
        if isinstance(module, LoraLayer):
            names.append(name)
    return names

lora_names = get_lora_module_names(model)   # `model` is your PEFT-wrapped model
print(f"🔢 Number of LoRA modules: {len(lora_names)}\n")

# for n in lora_names:
    # print(" ", n)
num_lora_modules = len(lora_names)
TOTAL_RANK_BUDGET = rank * num_lora_modules

avg_rank_per_module = TOTAL_RANK_BUDGET / num_lora_modules
print(
    f"💡 With TOTAL_RANK_BUDGET={TOTAL_RANK_BUDGET} over "
    f"{num_lora_modules} modules, avg rank ≈ {avg_rank_per_module:.2f}"
)
# Out:
# 🔢 Number of LoRA modules: 154
#
# 💡 With TOTAL_RANK_BUDGET=924 over 154 modules, avg rank ≈ 6.00

# %%
adaptive_callback = AdaptiveLoRACallback(
    val_dataloader=val_dataloader,
    total_rank=TOTAL_RANK_BUDGET,
    tau=0.9,
    min_rank=4,
    validate_batch_size=eval_batch_size,
    verbose=True,
)

# %%
accuracy = evaluate.load("accuracy")

def compute_metrics(eval_pred):
    logits, labels = eval_pred
    preds = logits.argmax(axis=-1)
    acc = accuracy.compute(predictions=preds, references=labels)
    return {"accuracy": acc["accuracy"]}

training_args = TrainingArguments(
    output_dir=output_dir,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=eval_batch_size,
    learning_rate=learning_rate,
    weight_decay=weight_decay,
    num_train_epochs=num_train_epochs,
    eval_strategy="epoch",
    save_strategy="epoch",
    logging_strategy="steps",
    logging_steps=100,
    save_total_limit=2,
    load_best_model_at_end=True,
    metric_for_best_model="accuracy",
    seed=seed,
    fp16=False,
    bf16=True,
    push_to_hub=False,
    report_to="none",
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=eval_dataset,
    tokenizer=tokenizer,
    data_collator=data_collator,
    compute_metrics=compute_metrics,
    callbacks=[adaptive_callback]
)

# -------------------------
# Train
# -------------------------
print("Starting training...")
trainer.train()

# Save model + adapter
print("Saving model and adapters...")
trainer.save_model(output_dir)
print("Saved model to", output_dir)

# If using PEFT, adapter weights are saved alongside model files.
# Out:
# Downloading builder script: 0.00B [00:00, ?B/s]
# /tmp/ipykernel_24/1749120520.py:30: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
# Starting training...
#
# --- AdaptiveLoRA: Preparing ranks for Epoch 1 ---
# Computing BI importance scores (pre-training)...
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Computing BI scores:   0%|          | 0/47 [00:00<?, ?it/s]
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Allocating new ranks based on BI scores...
# Applying new ranks to LoRA modules for this epoch...
#   - base_model.model.model.layers.0.self_attn.q_proj: r=6 (Unchanged, Score: 0.9899)
#   - base_model.model.model.layers.0.self_attn.k_proj: r=6 → 7 (Score: 1.0000)
#   - base_model.model.model.layers.0.self_attn.v_proj: r=6 (Unchanged, Score: 0.9973)
#   - base_model.model.model.layers.0.self_attn.o_proj: r=6 → 5 (Score: 0.9792)
#   - base_model.model.model.layers.0.mlp.gate_proj: r=6 (Unchanged, Score: 0.9958)
#   - base_model.model.model.layers.0.mlp.up_proj: r=6 (Unchanged, Score: 0.9986)
#   - base_model.model.model.layers.0.mlp.down_proj: r=6 (Unchanged, Score: 0.9957)
#   - base_model.model.model.layers.1.self_attn.q_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.1.self_attn.k_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.1.self_attn.v_proj: r=6 (Unchanged, Score: 0.9880)
#   - base_model.model.model.layers.1.self_attn.o_proj: r=6 (Unchanged, Score: 0.9932)
#   - base_model.model.model.layers.1.mlp.gate_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.1.mlp.up_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.1.mlp.down_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.2.self_attn.q_proj: r=6 (Unchanged, Score: 0.9909)
#   - base_model.model.model.layers.2.self_attn.k_proj: r=6 (Unchanged, Score: 0.9928)
#   - base_model.model.model.layers.2.self_attn.v_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.2.self_attn.o_proj: r=6 (Unchanged, Score: 0.9886)
#   - base_model.model.model.layers.2.mlp.gate_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.2.mlp.up_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.2.mlp.down_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.3.self_attn.q_proj: r=6 (Unchanged, Score: 0.9854)
#   - base_model.model.model.layers.3.self_attn.k_proj: r=6 (Unchanged, Score: 0.9993)
#   - base_model.model.model.layers.3.self_attn.v_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.3.self_attn.o_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.3.mlp.gate_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.3.mlp.up_proj: r=6 (Unchanged, Score: 0.9896)
#   - base_model.model.model.layers.3.mlp.down_proj: r=6 (Unchanged, Score: 0.9978)
#   - base_model.model.model.layers.4.self_attn.q_proj: r=6 (Unchanged, Score: 0.9909)
#   - base_model.model.model.layers.4.self_attn.k_proj: r=6 (Unchanged, Score: 0.9981)
#   - base_model.model.model.layers.4.self_attn.v_proj: r=6 (Unchanged, Score: 0.9944)
#   - base_model.model.model.layers.4.self_attn.o_proj: r=6 (Unchanged, Score: 0.9922)
#   - base_model.model.model.layers.4.mlp.gate_proj: r=6 (Unchanged, Score: 0.9897)
#   - base_model.model.model.layers.4.mlp.up_proj: r=6 (Unchanged, Score: 0.9981)
#   - base_model.model.model.layers.4.mlp.down_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.5.self_attn.q_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.5.self_attn.k_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.5.self_attn.v_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.5.self_attn.o_proj: r=6 (Unchanged, Score: 0.9982)
#   - base_model.model.model.layers.5.mlp.gate_proj: r=6 (Unchanged, Score: 0.9895)
#   - base_model.model.model.layers.5.mlp.up_proj: r=6 (Unchanged, Score: 0.9985)
#   - base_model.model.model.layers.5.mlp.down_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.6.self_attn.q_proj: r=6 (Unchanged, Score: 0.9840)
#   - base_model.model.model.layers.6.self_attn.k_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.6.self_attn.v_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.6.self_attn.o_proj: r=6 (Unchanged, Score: 0.9911)
#   - base_model.model.model.layers.6.mlp.gate_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.6.mlp.up_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.6.mlp.down_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.7.self_attn.q_proj: r=6 (Unchanged, Score: 0.9976)
#   - base_model.model.model.layers.7.self_attn.k_proj: r=6 (Unchanged, Score: 0.9812)
#   - base_model.model.model.layers.7.self_attn.v_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.7.self_attn.o_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.7.mlp.gate_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.7.mlp.up_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.7.mlp.down_proj: r=6 (Unchanged, Score: 0.9966)
#   - base_model.model.model.layers.8.self_attn.q_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.8.self_attn.k_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.8.self_attn.v_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.8.self_attn.o_proj: r=6 → 5 (Score: 0.9665)
#   - base_model.model.model.layers.8.mlp.gate_proj: r=6 (Unchanged, Score: 0.9906)
#   - base_model.model.model.layers.8.mlp.up_proj: r=6 (Unchanged, Score: 0.9951)
#   - base_model.model.model.layers.8.mlp.down_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.9.self_attn.q_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.9.self_attn.k_proj: r=6 → 5 (Score: 0.9686)
#   - base_model.model.model.layers.9.self_attn.v_proj: r=6 (Unchanged, Score: 0.9951)
#   - base_model.model.model.layers.9.self_attn.o_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.9.mlp.gate_proj: r=6 (Unchanged, Score: 0.9912)
#   - base_model.model.model.layers.9.mlp.up_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.9.mlp.down_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.10.self_attn.q_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.10.self_attn.k_proj: r=6 → 5 (Score: 0.9757)
#   - base_model.model.model.layers.10.self_attn.v_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.10.self_attn.o_proj: r=6 (Unchanged, Score: 0.9927)
#   - base_model.model.model.layers.10.mlp.gate_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.10.mlp.up_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.10.mlp.down_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.11.self_attn.q_proj: r=6 (Unchanged, Score: 0.9991)
#   - base_model.model.model.layers.11.self_attn.k_proj: r=6 (Unchanged, Score: 0.9917)
#   - base_model.model.model.layers.11.self_attn.v_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.11.self_attn.o_proj: r=6 (Unchanged, Score: 0.9972)
#   - base_model.model.model.layers.11.mlp.gate_proj: r=6 (Unchanged, Score: 0.9922)
#   - base_model.model.model.layers.11.mlp.up_proj: r=6 → 7 (Score: 1.0000)
#   - base_model.model.model.layers.11.mlp.down_proj: r=6 → 7 (Score: 1.0000)
#   - base_model.model.model.layers.12.self_attn.q_proj: r=6 → 7 (Score: 1.0000)
#   - base_model.model.model.layers.12.self_attn.k_proj: r=6 → 4 (Score: 0.9240)
#   - base_model.model.model.layers.12.self_attn.v_proj: r=6 (Unchanged, Score: 0.9963)
#   - base_model.model.model.layers.12.self_attn.o_proj: r=6 → 7 (Score: 1.0000)
#   - base_model.model.model.layers.12.mlp.gate_proj: r=6 → 7 (Score: 1.0000)
#   - base_model.model.model.layers.12.mlp.up_proj: r=6 → 7 (Score: 1.0000)
#   - base_model.model.model.layers.12.mlp.down_proj: r=6 (Unchanged, Score: 0.9939)
#   - base_model.model.model.layers.13.self_attn.q_proj: r=6 → 7 (Score: 1.0000)
#   - base_model.model.model.layers.13.self_attn.k_proj: r=6 → 4 (Score: 0.8732)
#   - base_model.model.model.layers.13.self_attn.v_proj: r=6 → 7 (Score: 1.0000)
#   - base_model.model.model.layers.13.self_attn.o_proj: r=6 (Unchanged, Score: 0.9922)
#   - base_model.model.model.layers.13.mlp.gate_proj: r=6 (Unchanged, Score: 0.9907)
#   - base_model.model.model.layers.13.mlp.up_proj: r=6 (Unchanged, Score: 0.9979)
#   - base_model.model.model.layers.13.mlp.down_proj: r=6 → 7 (Score: 1.0000)
#   - base_model.model.model.layers.14.self_attn.q_proj: r=6 → 7 (Score: 1.0000)
#   - base_model.model.model.layers.14.self_attn.k_proj: r=6 → 5 (Score: 0.9692)
#   - base_model.model.model.layers.14.self_attn.v_proj: r=6 → 7 (Score: 1.0000)
#   - base_model.model.model.layers.14.self_attn.o_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.14.mlp.gate_proj: r=6 (Unchanged, Score: 0.9864)
#   - base_model.model.model.layers.14.mlp.up_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.14.mlp.down_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.15.self_attn.q_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.15.self_attn.k_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.15.self_attn.v_proj: r=6 → 5 (Score: 0.9766)
#   - base_model.model.model.layers.15.self_attn.o_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.15.mlp.gate_proj: r=6 (Unchanged, Score: 0.9990)
#   - base_model.model.model.layers.15.mlp.up_proj: r=6 (Unchanged, Score: 0.9857)
#   - base_model.model.model.layers.15.mlp.down_proj: r=6 (Unchanged, Score: 0.9988)
#   - base_model.model.model.layers.16.self_attn.q_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.16.self_attn.k_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.16.self_attn.v_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.16.self_attn.o_proj: r=6 (Unchanged, Score: 0.9958)
#   - base_model.model.model.layers.16.mlp.gate_proj: r=6 (Unchanged, Score: 0.9866)
#   - base_model.model.model.layers.16.mlp.up_proj: r=6 (Unchanged, Score: 0.9854)
#   - base_model.model.model.layers.16.mlp.down_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.17.self_attn.q_proj: r=6 → 5 (Score: 0.9652)
#   - base_model.model.model.layers.17.self_attn.k_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.17.self_attn.v_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.17.self_attn.o_proj: r=6 (Unchanged, Score: 0.9969)
#   - base_model.model.model.layers.17.mlp.gate_proj: r=6 (Unchanged, Score: 0.9962)
#   - base_model.model.model.layers.17.mlp.up_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.17.mlp.down_proj: r=6 → 7 (Score: 1.0000)
#   - base_model.model.model.layers.18.self_attn.q_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.18.self_attn.k_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.18.self_attn.v_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.18.self_attn.o_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.18.mlp.gate_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.18.mlp.up_proj: r=6 (Unchanged, Score: 0.9880)
#   - base_model.model.model.layers.18.mlp.down_proj: r=6 (Unchanged, Score: 0.9933)
#   - base_model.model.model.layers.19.self_attn.q_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.19.self_attn.k_proj: r=6 → 4 (Score: 0.9158)
#   - base_model.model.model.layers.19.self_attn.v_proj: r=6 → 5 (Score: 0.9587)
#   - base_model.model.model.layers.19.self_attn.o_proj: r=6 (Unchanged, Score: 0.9905)
#   - base_model.model.model.layers.19.mlp.gate_proj: r=6 (Unchanged, Score: 0.9867)
#   - base_model.model.model.layers.19.mlp.up_proj: r=6 → 7 (Score: 1.0000)
#   - base_model.model.model.layers.19.mlp.down_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.20.self_attn.q_proj: r=6 → 5 (Score: 0.9799)
#   - base_model.model.model.layers.20.self_attn.k_proj: r=6 (Unchanged, Score: 0.9899)
#   - base_model.model.model.layers.20.self_attn.v_proj: r=6 → 7 (Score: 1.0000)
#   - base_model.model.model.layers.20.self_attn.o_proj: r=6 (Unchanged, Score: 0.9988)
#   - base_model.model.model.layers.20.mlp.gate_proj: r=6 → 7 (Score: 1.0000)
#   - base_model.model.model.layers.20.mlp.up_proj: r=6 (Unchanged, Score: 0.9982)
#   - base_model.model.model.layers.20.mlp.down_proj: r=6 (Unchanged, Score: 0.9915)
#   - base_model.model.model.layers.21.self_attn.q_proj: r=6 → 7 (Score: 1.0000)
#   - base_model.model.model.layers.21.self_attn.k_proj: r=6 (Unchanged, Score: 0.9854)
#   - base_model.model.model.layers.21.self_attn.v_proj: r=6 → 5 (Score: 0.9757)
#   - base_model.model.model.layers.21.self_attn.o_proj: r=6 (Unchanged, Score: 0.9954)
#   - base_model.model.model.layers.21.mlp.gate_proj: r=6 → 7 (Score: 1.0000)
#   - base_model.model.model.layers.21.mlp.up_proj: r=6 → 7 (Score: 1.0000)
#   - base_model.model.model.layers.21.mlp.down_proj: r=6 → 7 (Score: 1.0000)
# ✅ AdaptiveLoRA: Rank setup for Epoch 1 complete.
#     <div>
#
#       <progress value='1875' max='1875' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1875/1875 2:15:59, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.420400</td>
#       <td>0.403251</td>
#       <td>0.832000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.350300</td>
#       <td>0.384442</td>
#       <td>0.833333</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.303300</td>
#       <td>0.374463</td>
#       <td>0.843333</td>
#     </tr>
#   </tbody>
# </table><p>
# 📄 Epoch 1: Rank allocations logged to ./logs/adaptive_lora_epoch_logs.csv
#
#
# --- AdaptiveLoRA: Preparing ranks for Epoch 2 ---
# Computing BI importance scores (pre-training)...
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Computing BI scores:   0%|          | 0/47 [00:00<?, ?it/s]
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Allocating new ranks based on BI scores...
# Applying new ranks to LoRA modules for this epoch...
#   - base_model.model.model.layers.0.self_attn.q_proj: r=6 (Unchanged, Score: 0.9899)
#   - base_model.model.model.layers.0.self_attn.k_proj: r=7 → 6 (Score: 1.0000)
#   - base_model.model.model.layers.0.self_attn.v_proj: r=6 (Unchanged, Score: 0.9967)
#   - base_model.model.model.layers.0.self_attn.o_proj: r=5 → 6 (Score: 0.9805)
#   - base_model.model.model.layers.0.mlp.gate_proj: r=6 (Unchanged, Score: 0.9963)
#   - base_model.model.model.layers.0.mlp.up_proj: r=6 (Unchanged, Score: 0.9981)
#   - base_model.model.model.layers.0.mlp.down_proj: r=6 (Unchanged, Score: 0.9957)
#   - base_model.model.model.layers.1.self_attn.q_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.1.self_attn.k_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.1.self_attn.v_proj: r=6 (Unchanged, Score: 0.9879)
#   - base_model.model.model.layers.1.self_attn.o_proj: r=6 (Unchanged, Score: 0.9931)
#   - base_model.model.model.layers.1.mlp.gate_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.1.mlp.up_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.1.mlp.down_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.2.self_attn.q_proj: r=6 (Unchanged, Score: 0.9904)
#   - base_model.model.model.layers.2.self_attn.k_proj: r=6 (Unchanged, Score: 0.9940)
#   - base_model.model.model.layers.2.self_attn.v_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.2.self_attn.o_proj: r=6 (Unchanged, Score: 0.9830)
#   - base_model.model.model.layers.2.mlp.gate_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.2.mlp.up_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.2.mlp.down_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.3.self_attn.q_proj: r=6 (Unchanged, Score: 0.9862)
#   - base_model.model.model.layers.3.self_attn.k_proj: r=6 (Unchanged, Score: 0.9958)
#   - base_model.model.model.layers.3.self_attn.v_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.3.self_attn.o_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.3.mlp.gate_proj: r=6 (Unchanged, Score: 0.9988)
#   - base_model.model.model.layers.3.mlp.up_proj: r=6 (Unchanged, Score: 0.9913)
#   - base_model.model.model.layers.3.mlp.down_proj: r=6 (Unchanged, Score: 0.9980)
#   - base_model.model.model.layers.4.self_attn.q_proj: r=6 (Unchanged, Score: 0.9907)
#   - base_model.model.model.layers.4.self_attn.k_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.4.self_attn.v_proj: r=6 (Unchanged, Score: 0.9933)
#   - base_model.model.model.layers.4.self_attn.o_proj: r=6 (Unchanged, Score: 0.9957)
#   - base_model.model.model.layers.4.mlp.gate_proj: r=6 (Unchanged, Score: 0.9894)
#   - base_model.model.model.layers.4.mlp.up_proj: r=6 (Unchanged, Score: 0.9981)
#   - base_model.model.model.layers.4.mlp.down_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.5.self_attn.q_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.5.self_attn.k_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.5.self_attn.v_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.5.self_attn.o_proj: r=6 (Unchanged, Score: 0.9921)
#   - base_model.model.model.layers.5.mlp.gate_proj: r=6 (Unchanged, Score: 0.9876)
#   - base_model.model.model.layers.5.mlp.up_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.5.mlp.down_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.6.self_attn.q_proj: r=6 (Unchanged, Score: 0.9838)
#   - base_model.model.model.layers.6.self_attn.k_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.6.self_attn.v_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.6.self_attn.o_proj: r=6 (Unchanged, Score: 0.9960)
#   - base_model.model.model.layers.6.mlp.gate_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.6.mlp.up_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.6.mlp.down_proj: r=6 (Unchanged, Score: 0.9982)
#   - base_model.model.model.layers.7.self_attn.q_proj: r=6 (Unchanged, Score: 0.9948)
#   - base_model.model.model.layers.7.self_attn.k_proj: r=6 (Unchanged, Score: 0.9869)
#   - base_model.model.model.layers.7.self_attn.v_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.7.self_attn.o_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.7.mlp.gate_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.7.mlp.up_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.7.mlp.down_proj: r=6 (Unchanged, Score: 0.9967)
#   - base_model.model.model.layers.8.self_attn.q_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.8.self_attn.k_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.8.self_attn.v_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.8.self_attn.o_proj: r=5 (Unchanged, Score: 0.9764)
#   - base_model.model.model.layers.8.mlp.gate_proj: r=6 (Unchanged, Score: 0.9865)
#   - base_model.model.model.layers.8.mlp.up_proj: r=6 (Unchanged, Score: 0.9977)
#   - base_model.model.model.layers.8.mlp.down_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.9.self_attn.q_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.9.self_attn.k_proj: r=5 (Unchanged, Score: 0.9736)
#   - base_model.model.model.layers.9.self_attn.v_proj: r=6 (Unchanged, Score: 0.9898)
#   - base_model.model.model.layers.9.self_attn.o_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.9.mlp.gate_proj: r=6 (Unchanged, Score: 0.9898)
#   - base_model.model.model.layers.9.mlp.up_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.9.mlp.down_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.10.self_attn.q_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.10.self_attn.k_proj: r=5 → 6 (Score: 0.9820)
#   - base_model.model.model.layers.10.self_attn.v_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.10.self_attn.o_proj: r=6 (Unchanged, Score: 0.9966)
#   - base_model.model.model.layers.10.mlp.gate_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.10.mlp.up_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.10.mlp.down_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.11.self_attn.q_proj: r=6 → 7 (Score: 1.0000)
#   - base_model.model.model.layers.11.self_attn.k_proj: r=6 (Unchanged, Score: 0.9814)
#   - base_model.model.model.layers.11.self_attn.v_proj: r=6 → 7 (Score: 1.0000)
#   - base_model.model.model.layers.11.self_attn.o_proj: r=6 (Unchanged, Score: 0.9993)
#   - base_model.model.model.layers.11.mlp.gate_proj: r=6 (Unchanged, Score: 0.9918)
#   - base_model.model.model.layers.11.mlp.up_proj: r=7 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.11.mlp.down_proj: r=7 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.12.self_attn.q_proj: r=7 → 6 (Score: 1.0000)
#   - base_model.model.model.layers.12.self_attn.k_proj: r=4 (Unchanged, Score: 0.9064)
#   - base_model.model.model.layers.12.self_attn.v_proj: r=6 (Unchanged, Score: 0.9889)
#   - base_model.model.model.layers.12.self_attn.o_proj: r=7 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.12.mlp.gate_proj: r=7 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.12.mlp.up_proj: r=7 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.12.mlp.down_proj: r=6 (Unchanged, Score: 0.9985)
#   - base_model.model.model.layers.13.self_attn.q_proj: r=7 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.13.self_attn.k_proj: r=4 (Unchanged, Score: 0.8634)
#   - base_model.model.model.layers.13.self_attn.v_proj: r=7 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.13.self_attn.o_proj: r=6 (Unchanged, Score: 0.9923)
#   - base_model.model.model.layers.13.mlp.gate_proj: r=6 (Unchanged, Score: 0.9901)
#   - base_model.model.model.layers.13.mlp.up_proj: r=6 → 7 (Score: 1.0000)
#   - base_model.model.model.layers.13.mlp.down_proj: r=7 → 6 (Score: 1.0000)
#   - base_model.model.model.layers.14.self_attn.q_proj: r=7 → 6 (Score: 1.0000)
#   - base_model.model.model.layers.14.self_attn.k_proj: r=5 (Unchanged, Score: 0.9732)
#   - base_model.model.model.layers.14.self_attn.v_proj: r=7 → 6 (Score: 1.0000)
#   - base_model.model.model.layers.14.self_attn.o_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.14.mlp.gate_proj: r=6 (Unchanged, Score: 0.9861)
#   - base_model.model.model.layers.14.mlp.up_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.14.mlp.down_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.15.self_attn.q_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.15.self_attn.k_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.15.self_attn.v_proj: r=5 → 6 (Score: 0.9994)
#   - base_model.model.model.layers.15.self_attn.o_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.15.mlp.gate_proj: r=6 (Unchanged, Score: 0.9983)
#   - base_model.model.model.layers.15.mlp.up_proj: r=6 (Unchanged, Score: 0.9826)
#   - base_model.model.model.layers.15.mlp.down_proj: r=6 (Unchanged, Score: 0.9984)
#   - base_model.model.model.layers.16.self_attn.q_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.16.self_attn.k_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.16.self_attn.v_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.16.self_attn.o_proj: r=6 (Unchanged, Score: 0.9947)
#   - base_model.model.model.layers.16.mlp.gate_proj: r=6 (Unchanged, Score: 0.9835)
#   - base_model.model.model.layers.16.mlp.up_proj: r=6 (Unchanged, Score: 0.9891)
#   - base_model.model.model.layers.16.mlp.down_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.17.self_attn.q_proj: r=5 (Unchanged, Score: 0.9614)
#   - base_model.model.model.layers.17.self_attn.k_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.17.self_attn.v_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.17.self_attn.o_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.17.mlp.gate_proj: r=6 (Unchanged, Score: 0.9962)
#   - base_model.model.model.layers.17.mlp.up_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.17.mlp.down_proj: r=7 → 6 (Score: 1.0000)
#   - base_model.model.model.layers.18.self_attn.q_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.18.self_attn.k_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.18.self_attn.v_proj: r=6 (Unchanged, Score: 0.9984)
#   - base_model.model.model.layers.18.self_attn.o_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.18.mlp.gate_proj: r=6 (Unchanged, Score: 0.9998)
#   - base_model.model.model.layers.18.mlp.up_proj: r=6 (Unchanged, Score: 0.9864)
#   - base_model.model.model.layers.18.mlp.down_proj: r=6 (Unchanged, Score: 0.9974)
#   - base_model.model.model.layers.19.self_attn.q_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.19.self_attn.k_proj: r=4 (Unchanged, Score: 0.9339)
#   - base_model.model.model.layers.19.self_attn.v_proj: r=5 (Unchanged, Score: 0.9546)
#   - base_model.model.model.layers.19.self_attn.o_proj: r=6 (Unchanged, Score: 0.9952)
#   - base_model.model.model.layers.19.mlp.gate_proj: r=6 (Unchanged, Score: 0.9907)
#   - base_model.model.model.layers.19.mlp.up_proj: r=7 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.19.mlp.down_proj: r=6 → 7 (Score: 1.0000)
#   - base_model.model.model.layers.20.self_attn.q_proj: r=5 → 6 (Score: 0.9805)
#   - base_model.model.model.layers.20.self_attn.k_proj: r=6 (Unchanged, Score: 0.9870)
#   - base_model.model.model.layers.20.self_attn.v_proj: r=7 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.20.self_attn.o_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.20.mlp.gate_proj: r=7 → 6 (Score: 1.0000)
#   - base_model.model.model.layers.20.mlp.up_proj: r=6 (Unchanged, Score: 0.9978)
#   - base_model.model.model.layers.20.mlp.down_proj: r=6 (Unchanged, Score: 0.9919)
#   - base_model.model.model.layers.21.self_attn.q_proj: r=7 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.21.self_attn.k_proj: r=6 (Unchanged, Score: 0.9998)
#   - base_model.model.model.layers.21.self_attn.v_proj: r=5 (Unchanged, Score: 0.9785)
#   - base_model.model.model.layers.21.self_attn.o_proj: r=6 (Unchanged, Score: 0.9926)
#   - base_model.model.model.layers.21.mlp.gate_proj: r=7 → 6 (Score: 0.9987)
#   - base_model.model.model.layers.21.mlp.up_proj: r=7 → 6 (Score: 0.9987)
#   - base_model.model.model.layers.21.mlp.down_proj: r=7 (Unchanged, Score: 1.0000)
# ✅ AdaptiveLoRA: Rank setup for Epoch 2 complete.
#
# 📄 Epoch 2: Rank allocations logged to ./logs/adaptive_lora_epoch_logs.csv
#
#
# --- AdaptiveLoRA: Preparing ranks for Epoch 3 ---
# Computing BI importance scores (pre-training)...
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Computing BI scores:   0%|          | 0/47 [00:00<?, ?it/s]
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Allocating new ranks based on BI scores...
# Applying new ranks to LoRA modules for this epoch...
#   - base_model.model.model.layers.0.self_attn.q_proj: r=6 (Unchanged, Score: 0.9899)
#   - base_model.model.model.layers.0.self_attn.k_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.0.self_attn.v_proj: r=6 (Unchanged, Score: 0.9960)
#   - base_model.model.model.layers.0.self_attn.o_proj: r=6 (Unchanged, Score: 0.9807)
#   - base_model.model.model.layers.0.mlp.gate_proj: r=6 (Unchanged, Score: 0.9965)
#   - base_model.model.model.layers.0.mlp.up_proj: r=6 (Unchanged, Score: 0.9982)
#   - base_model.model.model.layers.0.mlp.down_proj: r=6 (Unchanged, Score: 0.9957)
#   - base_model.model.model.layers.1.self_attn.q_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.1.self_attn.k_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.1.self_attn.v_proj: r=6 (Unchanged, Score: 0.9886)
#   - base_model.model.model.layers.1.self_attn.o_proj: r=6 (Unchanged, Score: 0.9964)
#   - base_model.model.model.layers.1.mlp.gate_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.1.mlp.up_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.1.mlp.down_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.2.self_attn.q_proj: r=6 (Unchanged, Score: 0.9901)
#   - base_model.model.model.layers.2.self_attn.k_proj: r=6 (Unchanged, Score: 0.9947)
#   - base_model.model.model.layers.2.self_attn.v_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.2.self_attn.o_proj: r=6 (Unchanged, Score: 0.9857)
#   - base_model.model.model.layers.2.mlp.gate_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.2.mlp.up_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.2.mlp.down_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.3.self_attn.q_proj: r=6 (Unchanged, Score: 0.9866)
#   - base_model.model.model.layers.3.self_attn.k_proj: r=6 (Unchanged, Score: 0.9964)
#   - base_model.model.model.layers.3.self_attn.v_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.3.self_attn.o_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.3.mlp.gate_proj: r=6 (Unchanged, Score: 0.9985)
#   - base_model.model.model.layers.3.mlp.up_proj: r=6 (Unchanged, Score: 0.9913)
#   - base_model.model.model.layers.3.mlp.down_proj: r=6 (Unchanged, Score: 0.9980)
#   - base_model.model.model.layers.4.self_attn.q_proj: r=6 (Unchanged, Score: 0.9907)
#   - base_model.model.model.layers.4.self_attn.k_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.4.self_attn.v_proj: r=6 (Unchanged, Score: 0.9946)
#   - base_model.model.model.layers.4.self_attn.o_proj: r=6 (Unchanged, Score: 0.9932)
#   - base_model.model.model.layers.4.mlp.gate_proj: r=6 (Unchanged, Score: 0.9906)
#   - base_model.model.model.layers.4.mlp.up_proj: r=6 (Unchanged, Score: 0.9970)
#   - base_model.model.model.layers.4.mlp.down_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.5.self_attn.q_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.5.self_attn.k_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.5.self_attn.v_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.5.self_attn.o_proj: r=6 (Unchanged, Score: 0.9932)
#   - base_model.model.model.layers.5.mlp.gate_proj: r=6 (Unchanged, Score: 0.9862)
#   - base_model.model.model.layers.5.mlp.up_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.5.mlp.down_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.6.self_attn.q_proj: r=6 (Unchanged, Score: 0.9838)
#   - base_model.model.model.layers.6.self_attn.k_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.6.self_attn.v_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.6.self_attn.o_proj: r=6 (Unchanged, Score: 0.9976)
#   - base_model.model.model.layers.6.mlp.gate_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.6.mlp.up_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.6.mlp.down_proj: r=6 (Unchanged, Score: 0.9970)
#   - base_model.model.model.layers.7.self_attn.q_proj: r=6 (Unchanged, Score: 0.9953)
#   - base_model.model.model.layers.7.self_attn.k_proj: r=6 (Unchanged, Score: 0.9859)
#   - base_model.model.model.layers.7.self_attn.v_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.7.self_attn.o_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.7.mlp.gate_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.7.mlp.up_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.7.mlp.down_proj: r=6 (Unchanged, Score: 0.9961)
#   - base_model.model.model.layers.8.self_attn.q_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.8.self_attn.k_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.8.self_attn.v_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.8.self_attn.o_proj: r=5 → 6 (Score: 0.9798)
#   - base_model.model.model.layers.8.mlp.gate_proj: r=6 (Unchanged, Score: 0.9878)
#   - base_model.model.model.layers.8.mlp.up_proj: r=6 (Unchanged, Score: 0.9980)
#   - base_model.model.model.layers.8.mlp.down_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.9.self_attn.q_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.9.self_attn.k_proj: r=5 (Unchanged, Score: 0.9719)
#   - base_model.model.model.layers.9.self_attn.v_proj: r=6 (Unchanged, Score: 0.9895)
#   - base_model.model.model.layers.9.self_attn.o_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.9.mlp.gate_proj: r=6 (Unchanged, Score: 0.9910)
#   - base_model.model.model.layers.9.mlp.up_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.9.mlp.down_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.10.self_attn.q_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.10.self_attn.k_proj: r=6 (Unchanged, Score: 0.9786)
#   - base_model.model.model.layers.10.self_attn.v_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.10.self_attn.o_proj: r=6 (Unchanged, Score: 0.9957)
#   - base_model.model.model.layers.10.mlp.gate_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.10.mlp.up_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.10.mlp.down_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.11.self_attn.q_proj: r=7 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.11.self_attn.k_proj: r=6 (Unchanged, Score: 0.9808)
#   - base_model.model.model.layers.11.self_attn.v_proj: r=7 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.11.self_attn.o_proj: r=6 (Unchanged, Score: 0.9998)
#   - base_model.model.model.layers.11.mlp.gate_proj: r=6 (Unchanged, Score: 0.9915)
#   - base_model.model.model.layers.11.mlp.up_proj: r=7 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.11.mlp.down_proj: r=7 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.12.self_attn.q_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.12.self_attn.k_proj: r=4 (Unchanged, Score: 0.8982)
#   - base_model.model.model.layers.12.self_attn.v_proj: r=6 (Unchanged, Score: 0.9841)
#   - base_model.model.model.layers.12.self_attn.o_proj: r=7 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.12.mlp.gate_proj: r=7 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.12.mlp.up_proj: r=7 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.12.mlp.down_proj: r=6 (Unchanged, Score: 0.9991)
#   - base_model.model.model.layers.13.self_attn.q_proj: r=7 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.13.self_attn.k_proj: r=4 (Unchanged, Score: 0.8603)
#   - base_model.model.model.layers.13.self_attn.v_proj: r=7 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.13.self_attn.o_proj: r=6 (Unchanged, Score: 0.9928)
#   - base_model.model.model.layers.13.mlp.gate_proj: r=6 (Unchanged, Score: 0.9898)
#   - base_model.model.model.layers.13.mlp.up_proj: r=7 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.13.mlp.down_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.14.self_attn.q_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.14.self_attn.k_proj: r=5 (Unchanged, Score: 0.9725)
#   - base_model.model.model.layers.14.self_attn.v_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.14.self_attn.o_proj: r=6 (Unchanged, Score: 0.9998)
#   - base_model.model.model.layers.14.mlp.gate_proj: r=6 (Unchanged, Score: 0.9870)
#   - base_model.model.model.layers.14.mlp.up_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.14.mlp.down_proj: r=6 (Unchanged, Score: 0.9998)
#   - base_model.model.model.layers.15.self_attn.q_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.15.self_attn.k_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.15.self_attn.v_proj: r=6 (Unchanged, Score: 0.9960)
#   - base_model.model.model.layers.15.self_attn.o_proj: r=6 → 7 (Score: 1.0000)
#   - base_model.model.model.layers.15.mlp.gate_proj: r=6 (Unchanged, Score: 0.9991)
#   - base_model.model.model.layers.15.mlp.up_proj: r=6 (Unchanged, Score: 0.9825)
#   - base_model.model.model.layers.15.mlp.down_proj: r=6 (Unchanged, Score: 0.9993)
#   - base_model.model.model.layers.16.self_attn.q_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.16.self_attn.k_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.16.self_attn.v_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.16.self_attn.o_proj: r=6 (Unchanged, Score: 0.9958)
#   - base_model.model.model.layers.16.mlp.gate_proj: r=6 (Unchanged, Score: 0.9832)
#   - base_model.model.model.layers.16.mlp.up_proj: r=6 (Unchanged, Score: 0.9896)
#   - base_model.model.model.layers.16.mlp.down_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.17.self_attn.q_proj: r=5 (Unchanged, Score: 0.9612)
#   - base_model.model.model.layers.17.self_attn.k_proj: r=6 (Unchanged, Score: 0.9965)
#   - base_model.model.model.layers.17.self_attn.v_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.17.self_attn.o_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.17.mlp.gate_proj: r=6 (Unchanged, Score: 0.9951)
#   - base_model.model.model.layers.17.mlp.up_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.17.mlp.down_proj: r=6 (Unchanged, Score: 0.9983)
#   - base_model.model.model.layers.18.self_attn.q_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.18.self_attn.k_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.18.self_attn.v_proj: r=6 (Unchanged, Score: 0.9988)
#   - base_model.model.model.layers.18.self_attn.o_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.18.mlp.gate_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.18.mlp.up_proj: r=6 (Unchanged, Score: 0.9870)
#   - base_model.model.model.layers.18.mlp.down_proj: r=6 (Unchanged, Score: 0.9969)
#   - base_model.model.model.layers.19.self_attn.q_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.19.self_attn.k_proj: r=4 (Unchanged, Score: 0.9351)
#   - base_model.model.model.layers.19.self_attn.v_proj: r=5 (Unchanged, Score: 0.9532)
#   - base_model.model.model.layers.19.self_attn.o_proj: r=6 (Unchanged, Score: 0.9942)
#   - base_model.model.model.layers.19.mlp.gate_proj: r=6 (Unchanged, Score: 0.9915)
#   - base_model.model.model.layers.19.mlp.up_proj: r=7 → 6 (Score: 1.0000)
#   - base_model.model.model.layers.19.mlp.down_proj: r=7 → 6 (Score: 1.0000)
#   - base_model.model.model.layers.20.self_attn.q_proj: r=6 (Unchanged, Score: 0.9808)
#   - base_model.model.model.layers.20.self_attn.k_proj: r=6 (Unchanged, Score: 0.9861)
#   - base_model.model.model.layers.20.self_attn.v_proj: r=7 → 6 (Score: 1.0000)
#   - base_model.model.model.layers.20.self_attn.o_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.20.mlp.gate_proj: r=6 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.20.mlp.up_proj: r=6 (Unchanged, Score: 0.9983)
#   - base_model.model.model.layers.20.mlp.down_proj: r=6 (Unchanged, Score: 0.9917)
#   - base_model.model.model.layers.21.self_attn.q_proj: r=7 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.21.self_attn.k_proj: r=6 (Unchanged, Score: 0.9984)
#   - base_model.model.model.layers.21.self_attn.v_proj: r=5 → 6 (Score: 0.9792)
#   - base_model.model.model.layers.21.self_attn.o_proj: r=6 (Unchanged, Score: 0.9941)
#   - base_model.model.model.layers.21.mlp.gate_proj: r=6 (Unchanged, Score: 0.9990)
#   - base_model.model.model.layers.21.mlp.up_proj: r=6 (Unchanged, Score: 0.9985)
#   - base_model.model.model.layers.21.mlp.down_proj: r=7 (Unchanged, Score: 1.0000)
# ✅ AdaptiveLoRA: Rank setup for Epoch 3 complete.
#
# 📄 Epoch 3: Rank allocations logged to ./logs/adaptive_lora_epoch_logs.csv
#
# Saving model and adapters...
# Saved model to ./tinyllama-qnli-lora

# %%
results=trainer.evaluate()
print(results)
# Out:
#     <div>
#
#       <progress value='47' max='47' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [47/47 02:51]
#     </div>
# {'eval_loss': 0.3744634687900543, 'eval_accuracy': 0.8433333333333334, 'eval_runtime': 175.7871, 'eval_samples_per_second': 8.533, 'eval_steps_per_second': 0.267, 'epoch': 3.0}
